# %% [markdown]
# # Step 02: Using Variables in Prompts
#
# This notebook demonstrates how to use variables in prompts with Semantic Kernel.

# %%
import asyncio
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

from dotenv import load_dotenv, find_dotenv
dotenv_path = find_dotenv()
load_dotenv(dotenv_path, override=True)
# Out:
# True

# %%
async def main():
    kernel = Kernel()
    chat_completion = AzureChatCompletion()
    kernel.add_service(chat_completion)

    prompt = "What can I do near where I live {{$city}} at the moment {{$time}}?"

    response = await kernel.invoke_prompt(prompt=prompt, city="Jabalpur", time="1PM")
    print(response)

# %%
# Run the main function
await main()
# Out:
# As of 1 PM in Jabalpur, there are several activities you could consider depending on your interests and the current weather conditions. Here’s a mix of options:
#
# ### **Outdoor Activities:**
# 1. **Visit Bhedaghat:**
#    Take a trip to Bhedaghat to witness the stunning marble rocks and enjoy the calm waters of the Narmada River. Though the boating may happen later in the day or evening, you can still stroll and admire the scenery.
#
# 2. **Dhuandhar Falls:**
#    Head to Dhuandhar Falls for an energizing experience. It's a picturesque spot where you can enjoy the powerful waterfalls and capture some breathtaking photos.
#
# 3. **Madan Mahal Fort:**
#    Explore this historic fort, which offers panoramic views of Jabalpur and is surrounded by lush greenery with unique architectural ruins.
#
# ### **Cultural and Religious Spots:**
# 4. **Tripur Sundari Temple or Chausath Yogini Temple:**
# ...
