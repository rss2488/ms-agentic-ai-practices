# %% [markdown]
# # Step 01: Basic Semantic Kernel with Azure OpenAI
#
# This notebook demonstrates how to set up a basic Semantic Kernel with Azure OpenAI chat completion.

# %%
import asyncio
import os
from semantic_kernel import Kernel
from semantic_kernel.connectors.ai.open_ai import AzureChatCompletion

from dotenv import load_dotenv, find_dotenv
dotenv_path = find_dotenv()
load_dotenv(dotenv_path, override=True)
# Out:
# Found .env at: c:\Users\rshukla\ms-agentic-ai-practices\.env
# AZURE_OPENAI_ENDPOINT: https://aitrainingfoundryrss.openai.azure.com/

# %%
async def main():
    kernel = Kernel()
    chat_completion = AzureChatCompletion()
    kernel.add_service(chat_completion)

    prompt = "What can I do near where I live at the moment?"

    response = await kernel.invoke_prompt(prompt=prompt)
    print(response)

# %%
# Run the main function
await main()
# Out:
# I don’t have access to your location, but I’m happy to help guide you to things to do nearby! Could you share your city, region, or some details about your area? Let me know what kind of activity you're looking for—outdoors, dining, entertainment, shopping, or cultural experiences—and I’ll provide some ideas!
